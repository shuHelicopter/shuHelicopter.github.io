# %% [markdown]
# ## Macys.com Data Web Scraping Project

# %% [markdown]
# **Shu Liu, (shutel at hotmail dot com)**

# %% [markdown]
# I scraped the 'brand', 'link' and 'name' of 208898 items on Macy.com.

# %% [markdown]
# ### 1. Get the main categories

# %%
import time
import pandas as pd
import codecs
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.macys.com'

# %%
homepage = BeautifulSoup(requests.get(url, headers = {'user-agent': 'Scrapy_project'}).text, 'lxml')
mainCategories = homepage.find(id = 'mainNavigation').find_all('li', class_ = "fob")

# %%
cats = dict() # the dictionary used to store 'categories'
for elm in mainCategories:
    cats[elm.text.encode('utf-8').strip()] = url + elm.a['href'].strip()

# %% [markdown]
# ### 2. Explore the subcategories

# %% [markdown]
# The best way to explore all items on merchants' websites is to search by brands.

# %%
url_brands = cats['BRANDS']

# %% [markdown]
# ### Get links of all brands

# %%
brandspage = BeautifulSoup(requests.get(url_brands, headers = {'user-agent': 'Scrapy_project'}).text, 'lxml')

# %%
brands = dict()
brandbox = brandspage.find_all('div', class_ = 'brand-box')

# %%
for box in brandbox:
    for lst in box.find_all('ul'):
        for elm in lst.find_all('li'):
            brands[elm.text.encode('utf-8').strip()] = url + elm.a['href']

# %%
len(brands)
# Out:
# 1594

# %% [markdown]
# ### 3. Scrape items brand by brand

# %% [markdown]
# Save scraped data to local machine by brand:

# %%
def save_data(df, fil):
    f = codecs.open(fil, 'w', 'utf-8')
    f_df = pd.DataFrame(df)
    f_df.to_csv(fil)
    f.close()

# %% [markdown]
# Extract detailed information of items:

# %%
def item_name(df, brand, itempage):
    items = itempage.find('ul', class_= 'items large-block-grid-3').find_all('div', class_ = 'productDescription')
    for elm in items:
        item = dict()
        item['brand'] = brand
        item['name'] = elm.a['title'].encode('utf-8').strip()
        item['link'] = url + elm.a['href'].strip()
        df.append(item)

# %% [markdown]
# Items scraping:

# %%
i = 0 
for brand, url_item in brands.iteritems():
    i += 1
    try:
        if i % 10 == 0:
            time.sleep(5)
        print 'Brand %d: %s' % (i, brand)
        df = list()
        turning = True
        
        # Turning Page:
        while turning: 
            itempage = BeautifulSoup(requests.get(url_item, headers = {'user-agent': 'Scrapy_project'}).text, 'lxml')
            item_name(df, brand, itempage)
            turning = itempage.find('ul', class_= 'filters')
            if turning:
                turning = turning.find('li', class_ = 'nextPage') 
                if not turning or turning.a['href'].strip() == '#':
                    turning = False
                else:
                    url_item = url + turning.a['href'].strip() 
        print 'End of items scraping for *%s*' % brand
        
        fil = str(i) + '.csv'
        save_data(df, fil)
        
    except:
        print '********************** Error *****************'
        time.sleep(10) # restart
print 'End of scraping all items!'
# Out:
# Brand 500: New Era
# End of items scraping for *New Era*
# Brand 501: RIPE
# End of items scraping for *RIPE*
# Brand 502: Perry Ellis
# End of items scraping for *Perry Ellis*
# Brand 503: Cathy's Concepts
# End of items scraping for *Cathy's Concepts*
# Brand 504: Club Room
# End of items scraping for *Club Room*
# Brand 505: Kenroy Home
# End of items scraping for *Kenroy Home*
# Brand 506: Prada
# End of items scraping for *Prada*
# Brand 507: Steve Madden
# End of items scraping for *Steve Madden*
# Brand 508: B Darlin
# End of items scraping for *B Darlin*
# Brand 509: Fame and Partners
# End of items scraping for *Fame and Partners*
# Brand 510: SK-II
# End of items scraping for *SK-II*
# Brand 511: Vanity Fair
# End of items scraping for *Vanity Fair*
# Brand 512: Kelsi Dagger Brooklyn
# End of items scraping for *Kelsi Dagger Brooklyn*
# Brand 513: G by GUESS
# End of items scraping for *G by GUESS*
# Brand 514: Tristar
# End of items scraping for *Tristar*
# Brand 515: Darbie Angell
# End of items scraping for *Darbie Angell*
# Brand 516: Carolina Herrera
# End of items scraping for *Carolina Herrera*
# Brand 517: Dalyn
# End of items scraping for *Dalyn*
# Brand 518: Biaggi
# End of items scraping for *Biaggi*
# Brand 519: Eagle
# End of items scraping for *Eagle*
# Brand 520: Curve
# End of items scraping for *Curve*
# Brand 521: Tumi
# End of items scraping for *Tumi*
# Brand 522: Black Series
# End of items scraping for *Black Series*
# Brand 523: Elizabeth and James
# End of items scraping for *Elizabeth and James*
# Brand 524: Safavieh
# End of items scraping for *Safavieh*
# Brand 525: Baden
# End of items scraping for *Baden*
# Brand 526: Ricci Argentieri
# End of items scraping for *Ricci Argentieri*
# Brand 527: Under Armour
# End of items scraping for *Under Armour*
# Brand 528: Coco Reef
# End of items scraping for *Coco Reef*
# Brand 529: Fan Fever
# End of items scraping for *Fan Fever*
# Brand 530: Rawlings
# End of items scraping for *Rawlings*
# Brand 531: Sculptresse by Panache
# End of items scraping for *Sculptresse by Panache*
# Brand 532: Unlisted
# End of items scraping for *Unlisted*
# Brand 533: Rihanna
# End of items scraping for *Rihanna*
# Brand 534: Adrianna Papell
# End of items scraping for *Adrianna Papell*
# Brand 535: Joseph A
# End of items scraping for *Joseph A*
# Brand 536: Genevieve Gorder
# End of items scraping for *Genevieve Gorder*
# Brand 537: Junk Food
# End of items scraping for *Junk Food*
# Brand 538: Pink Rose
# End of items scraping for *Pink Rose*
# Brand 539: Laura Hart
# End of items scraping for *Laura Hart*
# Brand 540: aden by aden + anais
# End of items scraping for *aden by aden + anais*
# Brand 541: Donald Pliner
# End of items scraping for *Donald Pliner*
# Brand 542: Elf on the Shelf
# End of items scraping for *Elf on the Shelf*
# Brand 543: HipStyle
# End of items scraping for *HipStyle*
# Brand 544: Buffalo David Bitton
# End of items scraping for *Buffalo David Bitton*
# Brand 545: Jordan
# End of items scraping for *Jordan*
# Brand 546: Jimmy Choo
# End of items scraping for *Jimmy Choo*
# Brand 547: Ray-Ban
# End of items scraping for *Ray-Ban*
# Brand 548: Travelpro
# End of items scraping for *Travelpro*
# Brand 549: Truly Soft
# End of items scraping for *Truly Soft*
# Brand 550: Kenneth Cole Reaction
# End of items scraping for *Kenneth Cole Reaction*
# Brand 551: Swiss Army
# End of items scraping for *Swiss Army*
# Brand 552: Vogue
# End of items scraping for *Vogue*
# Brand 553: Lancôme
# End of items scraping for *Lancôme*
# Brand 554: Rachel Pally Maternity
# End of items scraping for *Rachel Pally Maternity*
# Brand 555: Ahava
# End of items scraping for *Ahava*
# Brand 556: Smeg
# End of items scraping for *Smeg*
# Brand 557: Badboy
# End of items scraping for *Badboy*
# Brand 558: Two Souls, One Love®
# End of items scraping for *Two Souls, One Love®*
# Brand 559: Jonathan Adler
# End of items scraping for *Jonathan Adler*
# Brand 560: Peri
# End of items scraping for *Peri*
# Brand 561: Innovative Technology
# End of items scraping for *Innovative Technology*
# Brand 562: Neatfreak
# End of items scraping for *Neatfreak*
# Brand 563: Wrapped in Love
# End of items scraping for *Wrapped in Love*
# Brand 564: SALAV
# End of items scraping for *SALAV*
# Brand 565: Pem America
# End of items scraping for *Pem America*
# Brand 566: Mugler
# End of items scraping for *Mugler*
# Brand 567: Bleu by Rod Beattie
# End of items scraping for *Bleu by Rod Beattie*
# Brand 568: Connected
# End of items scraping for *Connected*
# Brand 569: Drakkar
# End of items scraping for *Drakkar*
# Brand 570: Samsung
# End of items scraping for *Samsung*
# Brand 571: Montblanc
# End of items scraping for *Montblanc*
# Brand 572: L'Agent by Agent Provocateur
# End of items scraping for *L'Agent by Agent Provocateur*
# Brand 573: OXO
# End of items scraping for *OXO*
# Brand 574: NuFACE
# End of items scraping for *NuFACE*
# Brand 575: Aerogrow
# End of items scraping for *Aerogrow*
# Brand 576: Popz Topz
# End of items scraping for *Popz Topz*
# Brand 577: Flo Dancewear
# End of items scraping for *Flo Dancewear*
# Brand 578: Stearns & Foster
# End of items scraping for *Stearns & Foster*
# Brand 579: Wedgwood
# End of items scraping for *Wedgwood*
# Brand 580: Sabatier
# End of items scraping for *Sabatier*
# Brand 581: Osh Kosh
# End of items scraping for *Osh Kosh*
# Brand 582: Comfort Revolution
# End of items scraping for *Comfort Revolution*
# Brand 583: Masterbuilt
# End of items scraping for *Masterbuilt*
# Brand 584: Artland
# End of items scraping for *Artland*
# Brand 585: Citizen
# End of items scraping for *Citizen*
# Brand 586: Tervis Tumbler
# End of items scraping for *Tervis Tumbler*
# Brand 587: Daya by Zendaya
# End of items scraping for *Daya by Zendaya*
# Brand 588: Ren Wil
# End of items scraping for *Ren Wil*
# Brand 589: lonna & lilly
# End of items scraping for *lonna & lilly*
# Brand 590: Skyway
# End of items scraping for *Skyway*
# Brand 591: Victoria Classics
# End of items scraping for *Victoria Classics*
# Brand 592: Retro Brand
# End of items scraping for *Retro Brand*
# Brand 593: On the Verge
# End of items scraping for *On the Verge*
# Brand 594: Longines
# End of items scraping for *Longines*
# Brand 595: Gendarme
# End of items scraping for *Gendarme*
# Brand 596: Good Lad
# End of items scraping for *Good Lad*
# Brand 597: Incase
# End of items scraping for *Incase*
# Brand 598: endless rose
# End of items scraping for *endless rose*
# Brand 599: Merch Traffic
# End of items scraping for *Merch Traffic*
# Brand 600: Heelys
# End of items scraping for *Heelys*
# Brand 601: Elite Home
# End of items scraping for *Elite Home*
# Brand 602: Metrokane
# End of items scraping for *Metrokane*
# Brand 603: The Original Master Slicer
# End of items scraping for *The Original Master Slicer*
# Brand 604: Azzaro
# End of items scraping for *Azzaro*
# Brand 605: Estée Lauder
# End of items scraping for *Estée Lauder*
# Brand 606: Country Gentlemen
# End of items scraping for *Country Gentlemen*
# Brand 607: Jack by BB Dakota
# End of items scraping for *Jack by BB Dakota*
# Brand 608: M1858
# End of items scraping for *M1858*
# Brand 609: BLOW PRO
# End of items scraping for *BLOW PRO*
# Brand 610: FAO Schwarz
# End of items scraping for *FAO Schwarz*
# Brand 611: Nautica
# End of items scraping for *Nautica*
# Brand 612: Tools of the Trade
# End of items scraping for *Tools of the Trade*
# Brand 613: Party Animal
# End of items scraping for *Party Animal*
# Brand 614: Jockey
# End of items scraping for *Jockey*
# Brand 615: Rock & Candy
# End of items scraping for *Rock & Candy*
# Brand 616: Jaipur
# End of items scraping for *Jaipur*
# Brand 617: SHIFT
# End of items scraping for *SHIFT*
# Brand 618: Lanz of Salzburg
# End of items scraping for *Lanz of Salzburg*
# Brand 619: La Crosse Technology
# End of items scraping for *La Crosse Technology*
# Brand 620: Yankee Candle
# End of items scraping for *Yankee Candle*
# Brand 621: FOREO
# End of items scraping for *FOREO*
# Brand 622: Godinger
# End of items scraping for *Godinger*
# Brand 623: Tvilum
# End of items scraping for *Tvilum*
# Brand 624: Aerobed
# End of items scraping for *Aerobed*
# Brand 625: Lagostina
# End of items scraping for *Lagostina*
# Brand 626: Us Angels
# End of items scraping for *Us Angels*
# Brand 627: WoodWick Candle
# End of items scraping for *WoodWick Candle*
# Brand 628: The Fifth Season by Roberto Coin
# End of items scraping for *The Fifth Season by Roberto Coin*
# Brand 629: Bravado
# End of items scraping for *Bravado*
# Brand 630: Speechless
# End of items scraping for *Speechless*
# Brand 631: Ellison First Asia
# End of items scraping for *Ellison First Asia*
# Brand 632: Joseph Joseph
# End of items scraping for *Joseph Joseph*
# Brand 633: Paco Rabanne
# End of items scraping for *Paco Rabanne*
# Brand 634: Design Pac
# End of items scraping for *Design Pac*
# Brand 635: Mickey Mouse
# End of items scraping for *Mickey Mouse*
# Brand 636: Heart of Haiti
# End of items scraping for *Heart of Haiti*
# Brand 637: Bey-Berk
# End of items scraping for *Bey-Berk*
# Brand 638: Wendy Bellissimo
# End of items scraping for *Wendy Bellissimo*
# Brand 639: XSCAPE
# End of items scraping for *XSCAPE*
# Brand 640: City Studios
# End of items scraping for *City Studios*
# Brand 641: Say Yes to the Dress
# End of items scraping for *Say Yes to the Dress*
# Brand 642: SIS by Simone I Smith
# End of items scraping for *SIS by Simone I Smith*
# Brand 643: Kenneth Cole New York
# End of items scraping for *Kenneth Cole New York*
# Brand 644: Fitbit
# End of items scraping for *Fitbit*
# Brand 645: Emoji
# End of items scraping for *Emoji*
# Brand 646: Jack Spade
# End of items scraping for *Jack Spade*
# Brand 647: Betsy & Adam
# End of items scraping for *Betsy & Adam*
# Brand 648: Sweet Secrets Chocolate
# End of items scraping for *Sweet Secrets Chocolate*
# Brand 649: Bella Vita
# End of items scraping for *Bella Vita*
# Brand 650: Ballarini
# End of items scraping for *Ballarini*
# Brand 651: Bare Traps
# End of items scraping for *Bare Traps*
# Brand 652: Aflac
# End of items scraping for *Aflac*
# Brand 653: Design History
# End of items scraping for *Design History*
# Brand 654: S'Well®
# End of items scraping for *S'Well®*
# Brand 655: Vigoss Jeans
# End of items scraping for *Vigoss Jeans*
# Brand 656: Speedo
# End of items scraping for *Speedo*
# Brand 657: Presto
# End of items scraping for *Presto*
# Brand 658: Laura Geller Beauty
# End of items scraping for *Laura Geller Beauty*
# Brand 659: Triton
# End of items scraping for *Triton*
# Brand 660: Italian Gold
# End of items scraping for *Italian Gold*
# Brand 661: Larry Levine
# End of items scraping for *Larry Levine*
# Brand 662: INK+IVY
# End of items scraping for *INK+IVY*
# Brand 663: Coravin
# End of items scraping for *Coravin*
# Brand 664: Bassett Mirror
# End of items scraping for *Bassett Mirror*
# Brand 665: Callisto
# End of items scraping for *Callisto*
# Brand 666: Trans Pac
# End of items scraping for *Trans Pac*
# Brand 667: WILLIAM RAST
# End of items scraping for *WILLIAM RAST*
# Brand 668: twelveNYC
# End of items scraping for *twelveNYC*
# Brand 669: Modern Eternity
# End of items scraping for *Modern Eternity*
# Brand 670: Poetic Justice
# End of items scraping for *Poetic Justice*
# Brand 671: Beautiful Beginnings
# End of items scraping for *Beautiful Beginnings*
# Brand 672: PAW Patrol
# End of items scraping for *PAW Patrol*
# Brand 673: Elle Macpherson Intimates
# End of items scraping for *Elle Macpherson Intimates*
# Brand 674: Pacific Coast
# End of items scraping for *Pacific Coast*
# Brand 675: HANDS HIGH
# End of items scraping for *HANDS HIGH*
# Brand 676: Marc New York
# End of items scraping for *Marc New York*
# Brand 677: COOLA
# End of items scraping for *COOLA*
# Brand 678: Serta
# End of items scraping for *Serta*
# Brand 679: Skinnydip London
# End of items scraping for *Skinnydip London*
# Brand 680: Jessica Sanders
# End of items scraping for *Jessica Sanders*
# Brand 681: julia jordan
# End of items scraping for *julia jordan*
# Brand 682: Certified International
# End of items scraping for *Certified International*
# Brand 683: Germ Guardian
# End of items scraping for *Germ Guardian*
# Brand 684: Seattle Chocolates
# End of items scraping for *Seattle Chocolates*
# Brand 685: Global Goods Partners
# End of items scraping for *Global Goods Partners*
# Brand 686: Skechers
# End of items scraping for *Skechers*
# Brand 687: Angel by L. Martino
# End of items scraping for *Angel by L. Martino*
# Brand 688: The Fur Vault
# ********************** Error *****************
# Brand 689: Twiin
# End of items scraping for *Twiin*
# Brand 690: Bernardaud
# End of items scraping for *Bernardaud*
# Brand 691: Carven
# End of items scraping for *Carven*
# Brand 692: Robeez
# End of items scraping for *Robeez*
# Brand 693: Tom Ford
# End of items scraping for *Tom Ford*
# Brand 694: Melissa McCarthy Seven7
# End of items scraping for *Melissa McCarthy Seven7*
# Brand 695: Mezlan
# End of items scraping for *Mezlan*
# Brand 696: Karen Kane
# End of items scraping for *Karen Kane*
# Brand 697: Ryan Seacrest Distinction
# End of items scraping for *Ryan Seacrest Distinction*
# Brand 698: Sportula
# End of items scraping for *Sportula*
# Brand 699: Home Design
# End of items scraping for *Home Design*
# Brand 700: Escali
# End of items scraping for *Escali*
# Brand 701: MarieBelle New York
# End of items scraping for *MarieBelle New York*
# Brand 702: Weathertamer
# End of items scraping for *Weathertamer*
# Brand 703: Patchology
# End of items scraping for *Patchology*
# Brand 704: Spirit Activewear
# End of items scraping for *Spirit Activewear*
# Brand 705: J Kara
# End of items scraping for *J Kara*
# Brand 706: Quicksilver
# End of items scraping for *Quicksilver*
# Brand 707: BCBGMAXAZRIA
# End of items scraping for *BCBGMAXAZRIA*
# Brand 708: La Rochère
# End of items scraping for *La Rochère*
# Brand 709: Self E
# End of items scraping for *Self E*
# Brand 710: Marshall
# End of items scraping for *Marshall*
# Brand 711: JAMIE & LAYLA
# End of items scraping for *JAMIE & LAYLA*
# Brand 712: Chilewich
# End of items scraping for *Chilewich*
# Brand 713: BVLGARI
# End of items scraping for *BVLGARI*
# Brand 714: Hippie Rose
# End of items scraping for *Hippie Rose*
# Brand 715: American West
# End of items scraping for *American West*
# Brand 716: Hallmart Collectibles
# End of items scraping for *Hallmart Collectibles*
# Brand 717: C-Life
# End of items scraping for *C-Life*
# Brand 718: True Desire
# End of items scraping for *True Desire*
# Brand 719: Lunaire
# End of items scraping for *Lunaire*
# Brand 720: Profile
# ********************** Error *****************
# Brand 721: JAX
# End of items scraping for *JAX*
# Brand 722: E-Gift Card
# ********************** Error *****************
# Brand 723: Hula Honey
# End of items scraping for *Hula Honey*
# Brand 724: Saturday Knight
# End of items scraping for *Saturday Knight*
# Brand 725: Lichtenberg
# End of items scraping for *Lichtenberg*
# Brand 726: Laroma
# End of items scraping for *Laroma*
# Brand 727: Sesame Street
# End of items scraping for *Sesame Street*
# Brand 728: Nespresso
# End of items scraping for *Nespresso*
# Brand 729: Hudson NYC
# End of items scraping for *Hudson NYC*
# Brand 730: Capresso
# End of items scraping for *Capresso*
# Brand 731: Rialto
# End of items scraping for *Rialto*
# Brand 732: O'Neill
# End of items scraping for *O'Neill*
# Brand 733: Raymond Weil
# End of items scraping for *Raymond Weil*
# Brand 734: Step Ahead
# End of items scraping for *Step Ahead*
# Brand 735: Collective Concepts
# End of items scraping for *Collective Concepts*
# Brand 736: Old Time Hockey
# End of items scraping for *Old Time Hockey*
# Brand 737: Vera Bradley
# End of items scraping for *Vera Bradley*
# Brand 738: Hartmann
# End of items scraping for *Hartmann*
# Brand 739: Knickerbocker
# End of items scraping for *Knickerbocker*
# Brand 740: Vornado
# End of items scraping for *Vornado*
# Brand 741: Puma
# End of items scraping for *Puma*
# Brand 742: Donna Morgan
# End of items scraping for *Donna Morgan*
# Brand 743: Robert Lee Morris Soho
# End of items scraping for *Robert Lee Morris Soho*
# Brand 744: Samsonite
# End of items scraping for *Samsonite*
# Brand 745: Emporio Armani Swiss
# End of items scraping for *Emporio Armani Swiss*
# Brand 746: Juicy Couture
# End of items scraping for *Juicy Couture*
# Brand 747: Sutton by Rhona Sutton
# End of items scraping for *Sutton by Rhona Sutton*
# Brand 748: Love Squared
# End of items scraping for *Love Squared*
# Brand 749: Hunter Manufacturing
# End of items scraping for *Hunter Manufacturing*
# Brand 750: Metal Mulisha
# End of items scraping for *Metal Mulisha*
# Brand 751: Shavel
# End of items scraping for *Shavel*
# Brand 752: Jim Shore
# End of items scraping for *Jim Shore*
# Brand 753: Ninja
# End of items scraping for *Ninja*
# Brand 754: Crane
# End of items scraping for *Crane*
# Brand 755: Stacy Adams
# End of items scraping for *Stacy Adams*
# Brand 756: Sperry
# End of items scraping for *Sperry*
# Brand 757: Rampage
# End of items scraping for *Rampage*
# Brand 758: Pea in the Pod
# End of items scraping for *Pea in the Pod*
# Brand 759: Mitchell & Ness
# End of items scraping for *Mitchell & Ness*
# Brand 760: Dollhouse
# End of items scraping for *Dollhouse*
# Brand 761: Playtex
# End of items scraping for *Playtex*
# Brand 762: JM Collection
# End of items scraping for *JM Collection*
# Brand 763: Shark
# End of items scraping for *Shark*
# Brand 764: Forecaster
# End of items scraping for *Forecaster*
# Brand 765: littleBits
# End of items scraping for *littleBits*
# Brand 766: Coopersburg
# End of items scraping for *Coopersburg*
# Brand 767: Loloi
# End of items scraping for *Loloi*
# Brand 768: Majestic
# End of items scraping for *Majestic*
# Brand 769: Little Earth
# End of items scraping for *Little Earth*
# Brand 770: Madyson's Marshmallows
# End of items scraping for *Madyson's Marshmallows*
# Brand 771: Eyeshadow
# End of items scraping for *Eyeshadow*
# Brand 772: Penelope Mack
# End of items scraping for *Penelope Mack*
# Brand 773: BumpStart
# End of items scraping for *BumpStart*
# Brand 774: Wusthof
# End of items scraping for *Wusthof*
# Brand 775: Jay Franco
# End of items scraping for *Jay Franco*
# Brand 776: Loly in the sky
# End of items scraping for *Loly in the sky*
# Brand 777: London Fog
# End of items scraping for *London Fog*
# Brand 778: Rachael Ray
# End of items scraping for *Rachael Ray*
# Brand 779: Zephyr
# End of items scraping for *Zephyr*
# Brand 780: KORRES
# End of items scraping for *KORRES*
# Brand 781: American Rug Craftsmen
# End of items scraping for *American Rug Craftsmen*
# Brand 782: Articles of Society
# End of items scraping for *Articles of Society*
# Brand 783: Etonic
# End of items scraping for *Etonic*
# Brand 784: Propel RC
# End of items scraping for *Propel RC*
# Brand 785: Soffe
# End of items scraping for *Soffe*
# Brand 786: Style & Co
# End of items scraping for *Style & Co*
# Brand 787: Buxom Cosmetics
# End of items scraping for *Buxom Cosmetics*
# Brand 788: T3
# End of items scraping for *T3*
# Brand 789: For Bare Feet
# End of items scraping for *For Bare Feet*
# Brand 790: Teeze Me
# End of items scraping for *Teeze Me*
# Brand 791: Flora by Flora Nikrooz
# End of items scraping for *Flora by Flora Nikrooz*
# Brand 792: G.H. Bass & Co.
# End of items scraping for *G.H. Bass & Co.*
# Brand 793: Planet Gold
# End of items scraping for *Planet Gold*
# Brand 794: INGLOT
# End of items scraping for *INGLOT*
# Brand 795: Miss Elaine
# End of items scraping for *Miss Elaine*
# Brand 796: Lauren by Ralph Lauren Mens
# End of items scraping for *Lauren by Ralph Lauren Mens*
# Brand 797: Polaroid
# End of items scraping for *Polaroid*
# Brand 798: Margherita Kids
# End of items scraping for *Margherita Kids*
# Brand 799: Laundry by Shelli Segal
# End of items scraping for *Laundry by Shelli Segal*
# Brand 800: Nest
# End of items scraping for *Nest*
# Brand 801: Baby Fanatics
# End of items scraping for *Baby Fanatics*
# Brand 802: Mombasa
# End of items scraping for *Mombasa*
# Brand 803: Charter Club
# End of items scraping for *Charter Club*
# Brand 804: Aireloom
# End of items scraping for *Aireloom*
# Brand 805: Singer
# End of items scraping for *Singer*
# Brand 806: DL 1961
# End of items scraping for *DL 1961*
# Brand 807: Marvel
# End of items scraping for *Marvel*
# Brand 808: Oshkosh B'Gosh
# End of items scraping for *Oshkosh B'Gosh*
# Brand 809: Marc Jacobs
# End of items scraping for *Marc Jacobs*
# Brand 810: Clarins
# End of items scraping for *Clarins*
# Brand 811: Giorgio Armani
# End of items scraping for *Giorgio Armani*
# Brand 812: Umbra
# End of items scraping for *Umbra*
# Brand 813: Becca
# End of items scraping for *Becca*
# Brand 814: Jelly Belly
# End of items scraping for *Jelly Belly*
# Brand 815: SLINK Jeans
# End of items scraping for *SLINK Jeans*
# Brand 816: Blake Shelton
# End of items scraping for *Blake Shelton*
# Brand 817: Excell
# End of items scraping for *Excell*
# Brand 818: Atlantic
# End of items scraping for *Atlantic*
# Brand 819: Muk Luks
# End of items scraping for *Muk Luks*
# Brand 820: J.A. Henckels
# End of items scraping for *J.A. Henckels*
# Brand 821: Patricia Nash
# End of items scraping for *Patricia Nash*
# Brand 822: Nejma
# End of items scraping for *Nejma*
# Brand 823: Element
# End of items scraping for *Element*
# Brand 824: Mrs. Prindables
# End of items scraping for *Mrs. Prindables*
# Brand 825: Fan Ink
# End of items scraping for *Fan Ink*
# Brand 826: Central Park West
# End of items scraping for *Central Park West*
# Brand 827: Nina Ricci
# End of items scraping for *Nina Ricci*
# Brand 828: Primula
# End of items scraping for *Primula*
# Brand 829: Kenneth Mink
# End of items scraping for *Kenneth Mink*
# Brand 830: Asobu
# End of items scraping for *Asobu*
# Brand 831: Jennifer Adams Home
# End of items scraping for *Jennifer Adams Home*
# Brand 832: Tavik
# End of items scraping for *Tavik*
# Brand 833: Mizco
# End of items scraping for *Mizco*
# Brand 834: Ronni Nicole
# End of items scraping for *Ronni Nicole*
# Brand 835: Crock-Pot
# End of items scraping for *Crock-Pot*
# Brand 836: Jessica Howard
# End of items scraping for *Jessica Howard*
# Brand 837: Paul Sebastian
# End of items scraping for *Paul Sebastian*
# Brand 838: CLEAN Fragrance
# End of items scraping for *CLEAN Fragrance*
# Brand 839: J Brand
# End of items scraping for *J Brand*
# Brand 840: Pacific Coast Feather
# End of items scraping for *Pacific Coast Feather*
# Brand 841: Beats by Dr. Dre
# End of items scraping for *Beats by Dr. Dre*
# Brand 842: Dream Scene
# End of items scraping for *Dream Scene*
# Brand 843: Catherine Malandrino
# End of items scraping for *Catherine Malandrino*
# Brand 844: Carter's
# End of items scraping for *Carter's*
# Brand 845: Sonicare
# End of items scraping for *Sonicare*
# Brand 846: StriVectin
# End of items scraping for *StriVectin*
# Brand 847: Tahari
# End of items scraping for *Tahari*
# Brand 848: BOY MEETS GIRL.
# End of items scraping for *BOY MEETS GIRL.*
# Brand 849: Braun
# End of items scraping for *Braun*
# Brand 850: Elle
# End of items scraping for *Elle*
# Brand 851: Memory Company
# End of items scraping for *Memory Company*
# Brand 852: Baltic Linens
# End of items scraping for *Baltic Linens*
# Brand 853: Droga Chocolates
# End of items scraping for *Droga Chocolates*
# Brand 854: Vanilla Star
# End of items scraping for *Vanilla Star*
# Brand 855: Paul & Pitü Naturally
# End of items scraping for *Paul & Pitü Naturally*
# Brand 856: Johnson Bros.
# End of items scraping for *Johnson Bros.*
# Brand 857: Diadora
# End of items scraping for *Diadora*
# Brand 858: Gerber Childrenswear
# End of items scraping for *Gerber Childrenswear*
# Brand 859: Decorator's Lighting
# End of items scraping for *Decorator's Lighting*
# Brand 860: Evergreen Enterprises
# End of items scraping for *Evergreen Enterprises*
# Brand 861: Too Faced
# End of items scraping for *Too Faced*
# Brand 862: Belle Du Jour
# End of items scraping for *Belle Du Jour*
# Brand 863: DERMAdoctor
# End of items scraping for *DERMAdoctor*
# Brand 864: Hello Kitty
# End of items scraping for *Hello Kitty*
# Brand 865: Maui and Sons
# End of items scraping for *Maui and Sons*
# Brand 866: Johnston & Murphy
# End of items scraping for *Johnston & Murphy*
# Brand 867: Studio Mercantile
# End of items scraping for *Studio Mercantile*
# Brand 868: Click n Curl
# End of items scraping for *Click n Curl*
# Brand 869: Callaway
# End of items scraping for *Callaway*
# Brand 870: Caparros
# End of items scraping for *Caparros*
# Brand 871: Kandy Kiss
# End of items scraping for *Kandy Kiss*
# Brand 872: Danori
# End of items scraping for *Danori*
# Brand 873: Marmellata
# End of items scraping for *Marmellata*
# Brand 874: Swarovski
# End of items scraping for *Swarovski*
# Brand 875: Royal Luxe
# End of items scraping for *Royal Luxe*
# Brand 876: Neuhaus
# End of items scraping for *Neuhaus*
# Brand 877: Blue by Betsey Johnson
# End of items scraping for *Blue by Betsey Johnson*
# Brand 878: R.H. Macy & Co.
# ********************** Error *****************
# Brand 879: Marchesa by Lenox
# End of items scraping for *Marchesa by Lenox*
# Brand 880: Joy to the World
# End of items scraping for *Joy to the World*
# Brand 881: Coco Rave
# End of items scraping for *Coco Rave*
# Brand 882: Refinery
# End of items scraping for *Refinery*
# Brand 883: Stockdale
# End of items scraping for *Stockdale*
# Brand 884: Seven Dials
# End of items scraping for *Seven Dials*
# Brand 885: adidas
# End of items scraping for *adidas*
# Brand 886: Rado
# End of items scraping for *Rado*
# Brand 887: Nick Graham
# End of items scraping for *Nick Graham*
# Brand 888: Crystalift
# End of items scraping for *Crystalift*
# Brand 889: Miken
# End of items scraping for *Miken*
# Brand 890: Clarks
# End of items scraping for *Clarks*
# Brand 891: VESI
# End of items scraping for *VESI*
# Brand 892: White Mountain
# End of items scraping for *White Mountain*
# Brand 893: Touch by Alyssa Milano
# End of items scraping for *Touch by Alyssa Milano*
# Brand 894: Top Chef
# End of items scraping for *Top Chef*
# Brand 895: Belgique
# End of items scraping for *Belgique*
# Brand 896: Mare Mare
# End of items scraping for *Mare Mare*
# Brand 897: Swim Time
# End of items scraping for *Swim Time*
# Brand 898: Livex
# End of items scraping for *Livex*
# Brand 899: Team Beans
# End of items scraping for *Team Beans*
# Brand 900: Urban Habitat
# End of items scraping for *Urban Habitat*
# Brand 901: Sweet Romeo
# End of items scraping for *Sweet Romeo*
# Brand 902: Schmidt's
# End of items scraping for *Schmidt's*
# Brand 903: Bittermilk
# End of items scraping for *Bittermilk*
# Brand 904: Trina Turk
# End of items scraping for *Trina Turk*
# Brand 905: Tarte
# End of items scraping for *Tarte*
# Brand 906: BOSS Orange
# End of items scraping for *BOSS Orange*
# Brand 907: Apple Watch Nike+
# End of items scraping for *Apple Watch Nike+*
# Brand 908: Retrofit
# End of items scraping for *Retrofit*
# Brand 909: evian
# End of items scraping for *evian*
# Brand 910: Panasonic
# End of items scraping for *Panasonic*
# Brand 911: Brookstone
# End of items scraping for *Brookstone*
# Brand 912: Flying Monkey
# End of items scraping for *Flying Monkey*
# Brand 913: Michael Aram
# End of items scraping for *Michael Aram*
# Brand 914: MINKPINK
# End of items scraping for *MINKPINK*
# Brand 915: Coleman
# End of items scraping for *Coleman*
# Brand 916: Beauty and the Beast
# End of items scraping for *Beauty and the Beast*
# Brand 917: Baume & Mercier
# End of items scraping for *Baume & Mercier*
# Brand 918: Louis Raphael
# End of items scraping for *Louis Raphael*
# Brand 919: Mytex
# End of items scraping for *Mytex*
# Brand 920: Go Travel
# End of items scraping for *Go Travel*
# Brand 921: Nine West
# End of items scraping for *Nine West*
# Brand 922: m-61 by Bluemercury
# End of items scraping for *m-61 by Bluemercury*
# Brand 923: Benefit Cosmetics
# End of items scraping for *Benefit Cosmetics*
# Brand 924: Becca ETC
# End of items scraping for *Becca ETC*
# Brand 925: TruMiracle
# End of items scraping for *TruMiracle*
# Brand 926: Sachin & Babi
# ********************** Error *****************
# Brand 927: Ed Hardy
# End of items scraping for *Ed Hardy*
# Brand 928: Harry & David
# End of items scraping for *Harry & David*
# Brand 929: Shiseido
# End of items scraping for *Shiseido*
# Brand 930: IZUTECH
# End of items scraping for *IZUTECH*
# Brand 931: Mattel
# End of items scraping for *Mattel*
# Brand 932: Berlei
# End of items scraping for *Berlei*
# Brand 933: Badgley Mischka
# End of items scraping for *Badgley Mischka*
# Brand 934: Planet Sox
# End of items scraping for *Planet Sox*
# Brand 935: Issey Miyake
# End of items scraping for *Issey Miyake*
# Brand 936: Maui Jim
# End of items scraping for *Maui Jim*
# Brand 937: Frye
# End of items scraping for *Frye*
# Brand 938: Fila
# End of items scraping for *Fila*
# Brand 939: Seraphine
# End of items scraping for *Seraphine*
# Brand 940: GHD
# End of items scraping for *GHD*
# Brand 941: REEF
# End of items scraping for *REEF*
# Brand 942: Miss Chievous
# End of items scraping for *Miss Chievous*
# Brand 943: LINE
# End of items scraping for *LINE*
# Brand 944: Anna Sui
# End of items scraping for *Anna Sui*
# Brand 945: Anne Klein Petites
# End of items scraping for *Anne Klein Petites*
# Brand 946: Inspire Psyche Terry
# End of items scraping for *Inspire Psyche Terry*
# Brand 947: Black Daisy
# End of items scraping for *Black Daisy*
# Brand 948: Breville
# End of items scraping for *Breville*
# Brand 949: Weight Watchers
# End of items scraping for *Weight Watchers*
# Brand 950: 7 Sisters
# End of items scraping for *7 Sisters*
# Brand 951: Cacharel
# End of items scraping for *Cacharel*
# Brand 952: Fagor
# End of items scraping for *Fagor*
# Brand 953: Ellis Curtain
# End of items scraping for *Ellis Curtain*
# Brand 954: Betsey Johnson
# End of items scraping for *Betsey Johnson*
# Brand 955: Cangshan
# End of items scraping for *Cangshan*
# Brand 956: Babymel
# End of items scraping for *Babymel*
# Brand 957: New Agenda
# End of items scraping for *New Agenda*
# Brand 958: Gypsies & Moondust
# End of items scraping for *Gypsies & Moondust*
# Brand 959: Soft As A Grape
# End of items scraping for *Soft As A Grape*
# Brand 960: Family Pajamas
# End of items scraping for *Family Pajamas*
# Brand 961: Prada Linea Rossa
# End of items scraping for *Prada Linea Rossa*
# Brand 962: Pulsar
# End of items scraping for *Pulsar*
# Brand 963: Sure Fit
# End of items scraping for *Sure Fit*
# Brand 964: Torn Ranch
# End of items scraping for *Torn Ranch*
# Brand 965: College Kids
# End of items scraping for *College Kids*
# Brand 966: Balenciaga
# End of items scraping for *Balenciaga*
# Brand 967: Barbara Barry
# End of items scraping for *Barbara Barry*
# Brand 968: Sporto
# End of items scraping for *Sporto*
# Brand 969: Dolce & Gabbana
# End of items scraping for *Dolce & Gabbana*
# Brand 970: Fifth Sun
# End of items scraping for *Fifth Sun*
# Brand 971: Chinese Laundry
# End of items scraping for *Chinese Laundry*
# Brand 972: Mr. Beer
# End of items scraping for *Mr. Beer*
# Brand 973: Magicsuit
# End of items scraping for *Magicsuit*
# Brand 974: Martex
# End of items scraping for *Martex*
# Brand 975: Dior
# End of items scraping for *Dior*
# Brand 976: Report
# End of items scraping for *Report*
# Brand 977: Croscill
# End of items scraping for *Croscill*
# Brand 978: One Clothing
# End of items scraping for *One Clothing*
# Brand 979: Nina
# End of items scraping for *Nina*
# Brand 980: Kelly Ripa Home
# End of items scraping for *Kelly Ripa Home*
# Brand 981: Despicable Me
# End of items scraping for *Despicable Me*
# Brand 982: JHB Design
# End of items scraping for *JHB Design*
# Brand 983: Be Bop
# End of items scraping for *Be Bop*
# Brand 984: SensorGel
# End of items scraping for *SensorGel*
# Brand 985: Schoenhut
# End of items scraping for *Schoenhut*
# Brand 986: Concept One
# End of items scraping for *Concept One*
# Brand 987: Superdry
# End of items scraping for *Superdry*
# Brand 988: Monica Danko
# End of items scraping for *Monica Danko*
# Brand 989: Bobbi Brown
# End of items scraping for *Bobbi Brown*
# Brand 990: Pink Republic
# End of items scraping for *Pink Republic*
# Brand 991: MasterPieces Puzzle Company
# End of items scraping for *MasterPieces Puzzle Company*
# Brand 992: Robbie Bee
# End of items scraping for *Robbie Bee*
# Brand 993: Adesso
# End of items scraping for *Adesso*
# Brand 994: Dr. Bronner's
# End of items scraping for *Dr. Bronner's*
# Brand 995: Homewear
# End of items scraping for *Homewear*
# Brand 996: Brett Bros
# End of items scraping for *Brett Bros*
# Brand 997: Denim & Supply Ralph Lauren
# End of items scraping for *Denim & Supply Ralph Lauren*
# Brand 998: Wrapped
# End of items scraping for *Wrapped*
# Brand 999: Eight Sixty
# End of items scraping for *Eight Sixty*
# Brand 1000: NoJo
# End of items scraping for *NoJo*
# Brand 1001: Outerstuff
# End of items scraping for *Outerstuff*
# Brand 1002: NeuLash
# End of items scraping for *NeuLash*
# Brand 1003: Giani Bernini
# End of items scraping for *Giani Bernini*
# Brand 1004: Shedrain
# End of items scraping for *Shedrain*
# Brand 1005: X3
# End of items scraping for *X3*
# Brand 1006: Havaianas
# End of items scraping for *Havaianas*
# Brand 1007: Weatherproof Vintage
# End of items scraping for *Weatherproof Vintage*
# Brand 1008: Starter
# End of items scraping for *Starter*
# Brand 1009: Laura Mercier
# End of items scraping for *Laura Mercier*
# Brand 1010: Dr. Brandt
# End of items scraping for *Dr. Brandt*
# Brand 1011: DKNY
# End of items scraping for *DKNY*
# Brand 1012: Guerlain
# End of items scraping for *Guerlain*
# Brand 1013: Cosabella
# End of items scraping for *Cosabella*
# Brand 1014: Illume
# End of items scraping for *Illume*
# Brand 1015: Paige Denim
# End of items scraping for *Paige Denim*
# Brand 1016: PHYTO
# End of items scraping for *PHYTO*
# Brand 1017: Dockers
# End of items scraping for *Dockers*
# Brand 1018: Love, Fire
# End of items scraping for *Love, Fire*
# Brand 1019: Asics
# End of items scraping for *Asics*
# Brand 1020: Sanderson
# End of items scraping for *Sanderson*
# Brand 1021: OppoSuits
# End of items scraping for *OppoSuits*
# Brand 1022: Kid Made Modern
# End of items scraping for *Kid Made Modern*
# Brand 1023: Holiday Lane
# End of items scraping for *Holiday Lane*
# Brand 1024: Nowadays
# ********************** Error *****************
# Brand 1025: Dirty Laundry
# End of items scraping for *Dirty Laundry*
# Brand 1026: Easy Street
# End of items scraping for *Easy Street*
# Brand 1027: Homedics
# End of items scraping for *Homedics*
# Brand 1028: Boelter Brands
# End of items scraping for *Boelter Brands*
# Brand 1029: Hanes
# End of items scraping for *Hanes*
# Brand 1030: Esprit
# End of items scraping for *Esprit*
# Brand 1031: Trolls by DreamWorks
# End of items scraping for *Trolls by DreamWorks*
# Brand 1032: Hanna Andersson
# End of items scraping for *Hanna Andersson*
# Brand 1033: Macy's Impulse Beauty Collection
# End of items scraping for *Macy's Impulse Beauty Collection*
# Brand 1034: Westport
# End of items scraping for *Westport*
# Brand 1035: Rosie Pope
# End of items scraping for *Rosie Pope*
# Brand 1036: Bernardo
# End of items scraping for *Bernardo*
# Brand 1037: Checkered Flag Sports
# End of items scraping for *Checkered Flag Sports*
# Brand 1038: Lucid
# End of items scraping for *Lucid*
# Brand 1039: Polly & Esther
# End of items scraping for *Polly & Esther*
# Brand 1040: Charles David
# End of items scraping for *Charles David*
# Brand 1041: Silver Jeans Co.
# End of items scraping for *Silver Jeans Co.*
# Brand 1042: Cutter & Buck
# End of items scraping for *Cutter & Buck*
# Brand 1043: DOPE
# End of items scraping for *DOPE*
# Brand 1044: Woolrich
# End of items scraping for *Woolrich*
# Brand 1045: Zero Water
# End of items scraping for *Zero Water*
# Brand 1046: A|X Armani Exchange
# End of items scraping for *A|X Armani Exchange*
# Brand 1047: Jewel Badgley Mischka
# End of items scraping for *Jewel Badgley Mischka*
# Brand 1048: Google
# End of items scraping for *Google*
# Brand 1049: Authentic Comfort
# End of items scraping for *Authentic Comfort*
# Brand 1050: Reed & Barton
# End of items scraping for *Reed & Barton*
# Brand 1051: URBANEARS
# End of items scraping for *URBANEARS*
# Brand 1052: Emerald Sundae
# End of items scraping for *Emerald Sundae*
# Brand 1053: Springs
# End of items scraping for *Springs*
# Brand 1054: Apple Watch Edition
# End of items scraping for *Apple Watch Edition*
# Brand 1055: CHRLDR
# End of items scraping for *CHRLDR*
# Brand 1056: bareMinerals
# End of items scraping for *bareMinerals*
# Brand 1057: Birkenstock
# End of items scraping for *Birkenstock*
# Brand 1058: Briggs & Riley
# End of items scraping for *Briggs & Riley*
# Brand 1059: Easy Spirit
# End of items scraping for *Easy Spirit*
# Brand 1060: Fuzzy Babba
# End of items scraping for *Fuzzy Babba*
# Brand 1061: Strideline
# End of items scraping for *Strideline*
# Brand 1062: V. Fraas
# End of items scraping for *V. Fraas*
# Brand 1063: Alex Woo
# End of items scraping for *Alex Woo*
# Brand 1064: Nova Lighting
# End of items scraping for *Nova Lighting*
# Brand 1065: Penguin
# End of items scraping for *Penguin*
# Brand 1066: Judith Jack
# End of items scraping for *Judith Jack*
# Brand 1067: Lacoste Home
# End of items scraping for *Lacoste Home*
# Brand 1068: Diesel
# End of items scraping for *Diesel*
# Brand 1069: Sequin Hearts
# End of items scraping for *Sequin Hearts*
# Brand 1070: Epicurean
# End of items scraping for *Epicurean*
# Brand 1071: Sunglass Hut Collection
# End of items scraping for *Sunglass Hut Collection*
# Brand 1072: The Cellar
# End of items scraping for *The Cellar*
# Brand 1073: Minnie Mouse
# End of items scraping for *Minnie Mouse*
# Brand 1074: Society 43
# End of items scraping for *Society 43*
# Brand 1075: Hawke & Co. Outfitter
# End of items scraping for *Hawke & Co. Outfitter*
# Brand 1076: Knork
# End of items scraping for *Knork*
# Brand 1077: Foot Petals
# End of items scraping for *Foot Petals*
# Brand 1078: GUESS
# End of items scraping for *GUESS*
# Brand 1079: Team Golf
# End of items scraping for *Team Golf*
# Brand 1080: Katy Perry
# End of items scraping for *Katy Perry*
# Brand 1081: Fox
# End of items scraping for *Fox*
# Brand 1082: Sensorpedic
# End of items scraping for *Sensorpedic*
# Brand 1083: Kiehl's Since 1851
# End of items scraping for *Kiehl's Since 1851*
# Brand 1084: Zegna
# End of items scraping for *Zegna*
# Brand 1085: W&P Design
# End of items scraping for *W&P Design*
# Brand 1086: NARS
# End of items scraping for *NARS*
# Brand 1087: Spode
# End of items scraping for *Spode*
# Brand 1088: Feiss
# End of items scraping for *Feiss*
# Brand 1089: Martha Stewart Collection
# End of items scraping for *Martha Stewart Collection*
# Brand 1090: Aramis
# End of items scraping for *Aramis*
# Brand 1091: Brahmin
# End of items scraping for *Brahmin*
# Brand 1092: Atlanta Hosiery Company
# End of items scraping for *Atlanta Hosiery Company*
# Brand 1093: Granite Gear
# End of items scraping for *Granite Gear*
# Brand 1094: Hudson Jeans
# End of items scraping for *Hudson Jeans*
# Brand 1095: Luckies of London
# End of items scraping for *Luckies of London*
# Brand 1096: Kanu Surf
# End of items scraping for *Kanu Surf*
# Brand 1097: Van Heusen
# ********************** Error *****************
# Brand 1098: 2028
# End of items scraping for *2028*
# Brand 1099: Rico Industries
# End of items scraping for *Rico Industries*
# Brand 1100: Jack Mason
# End of items scraping for *Jack Mason*
# Brand 1101: Totes
# End of items scraping for *Totes*
# Brand 1102: Superman
# End of items scraping for *Superman*
# Brand 1103: Loveappella
# End of items scraping for *Loveappella*
# Brand 1104: Design Ideas
# End of items scraping for *Design Ideas*
# Brand 1105: GLOBAL
# End of items scraping for *GLOBAL*
# Brand 1106: Daniel Tiger's Neighborhood
# End of items scraping for *Daniel Tiger's Neighborhood*
# Brand 1107: A Pea in the Pod
# End of items scraping for *A Pea in the Pod*
# Brand 1108: Anolon
# End of items scraping for *Anolon*
# Brand 1109: Kenneth Cole
# End of items scraping for *Kenneth Cole*
# Brand 1110: Fossil
# End of items scraping for *Fossil*
# Brand 1111: Peanuts
# End of items scraping for *Peanuts*
# Brand 1112: Victoria
# End of items scraping for *Victoria*
# Brand 1113: Disney
# End of items scraping for *Disney*
# Brand 1114: Gibson
# End of items scraping for *Gibson*
# Brand 1115: Kidorable
# End of items scraping for *Kidorable*
# Brand 1116: Revere
# End of items scraping for *Revere*
# Brand 1117: 3Doodler
# End of items scraping for *3Doodler*
# Brand 1118: PROJECT SOCIAL T
# End of items scraping for *PROJECT SOCIAL T*
# Brand 1119: Say What?
# End of items scraping for *Say What?*
# Brand 1120: Carmen Marc Valvo
# End of items scraping for *Carmen Marc Valvo*
# Brand 1121: Indigo Blue
# End of items scraping for *Indigo Blue*
# Brand 1122: Kobi Halperin
# ********************** Error *****************
# Brand 1123: No Vendor
# End of items scraping for *No Vendor*
# Brand 1124: PAWZ
# End of items scraping for *PAWZ*
# Brand 1125: I AM
# End of items scraping for *I AM*
# Brand 1126: Wine Enthusiast
# End of items scraping for *Wine Enthusiast*
# Brand 1127: STEVEN by Steve Madden
# End of items scraping for *STEVEN by Steve Madden*
# Brand 1128: AG Adriano Goldschmied
# End of items scraping for *AG Adriano Goldschmied*
# Brand 1129: City Chic
# End of items scraping for *City Chic*
# Brand 1130: Platinum Collection
# End of items scraping for *Platinum Collection*
# Brand 1131: Travel Select
# End of items scraping for *Travel Select*
# Brand 1132: Almost Famous
# End of items scraping for *Almost Famous*
# Brand 1133: Bzees
# End of items scraping for *Bzees*
# Brand 1134: Elrene
# End of items scraping for *Elrene*
# Brand 1135: GreenPan
# End of items scraping for *GreenPan*
# Brand 1136: Paloma Picasso
# End of items scraping for *Paloma Picasso*
# Brand 1137: Oakley
# End of items scraping for *Oakley*
# Brand 1138: Forever Collectibles
# End of items scraping for *Forever Collectibles*
# Brand 1139: Just Cavalli
# End of items scraping for *Just Cavalli*
# Brand 1140: Longchamp
# End of items scraping for *Longchamp*
# Brand 1141: ban.do
# End of items scraping for *ban.do*
# Brand 1142: DIYVA by Barbara K
# End of items scraping for *DIYVA by Barbara K*
# Brand 1143: August Hats
# End of items scraping for *August Hats*
# Brand 1144: VRY WRM
# End of items scraping for *VRY WRM*
# Brand 1145: Pair of Thieves
# End of items scraping for *Pair of Thieves*
# Brand 1146: Morgan & Company
# End of items scraping for *Morgan & Company*
# Brand 1147: Noritake
# End of items scraping for *Noritake*
# Brand 1148: BEARPAW
# End of items scraping for *BEARPAW*
# Brand 1149: Tommy Bahama Home
# End of items scraping for *Tommy Bahama Home*
# Brand 1150: Simply Designz
# End of items scraping for *Simply Designz*
# Brand 1151: Movado
# End of items scraping for *Movado*
# Brand 1152: Anova
# End of items scraping for *Anova*
# Brand 1153: CCM
# End of items scraping for *CCM*
# Brand 1154: Circus by Sam Edelman
# End of items scraping for *Circus by Sam Edelman*
# Brand 1155: The Style Club
# End of items scraping for *The Style Club*
# Brand 1156: La Blanca
# End of items scraping for *La Blanca*
# Brand 1157: Eileen West
# End of items scraping for *Eileen West*
# Brand 1158: Department 56
# End of items scraping for *Department 56*
# Brand 1159: iTouch
# End of items scraping for *iTouch*
# Brand 1160: Petunia Pickle Bottom
# End of items scraping for *Petunia Pickle Bottom*
# Brand 1161: B BLOCK Headwear
# End of items scraping for *B BLOCK Headwear*
# Brand 1162: PLANT Apothecary
# End of items scraping for *PLANT Apothecary*
# Brand 1163: Madison Park
# End of items scraping for *Madison Park*
# Brand 1164: Avengers
# End of items scraping for *Avengers*
# Brand 1165: Shimmer and Shine
# End of items scraping for *Shimmer and Shine*
# Brand 1166: RARE Featuring GEMFIELDS
# End of items scraping for *RARE Featuring GEMFIELDS*
# Brand 1167: My Michelle
# End of items scraping for *My Michelle*
# Brand 1168: Palais des Thés
# End of items scraping for *Palais des Thés*
# Brand 1169: Bio Ionic
# End of items scraping for *Bio Ionic*
# Brand 1170: Antigua
# End of items scraping for *Antigua*
# Brand 1171: Pepper Creek Farms
# End of items scraping for *Pepper Creek Farms*
# Brand 1172: Liora Manne'
# End of items scraping for *Liora Manne'*
# Brand 1173: Joy Mangano
# End of items scraping for *Joy Mangano*
# Brand 1174: Tracy Porter
# End of items scraping for *Tracy Porter*
# Brand 1175: Unwritten
# End of items scraping for *Unwritten*
# Brand 1176: SprezzaBox
# End of items scraping for *SprezzaBox*
# Brand 1177: Twinkling Diamond Star
# End of items scraping for *Twinkling Diamond Star*
# Brand 1178: Ferragamo
# End of items scraping for *Ferragamo*
# Brand 1179: Harry Potter
# End of items scraping for *Harry Potter*
# Brand 1180: Ande
# End of items scraping for *Ande*
# Brand 1181: Hydraulic
# End of items scraping for *Hydraulic*
# Brand 1182: Rewash
# End of items scraping for *Rewash*
# Brand 1183: Wembley
# End of items scraping for *Wembley*
# Brand 1184: Weekend Max Mara
# End of items scraping for *Weekend Max Mara*
# Brand 1185: PJ Couture
# End of items scraping for *PJ Couture*
# Brand 1186: Home Essentials
# End of items scraping for *Home Essentials*
# Brand 1187: AME
# End of items scraping for *AME*
# Brand 1188: Belldini
# End of items scraping for *Belldini*
# Brand 1189: K-Swiss
# End of items scraping for *K-Swiss*
# Brand 1190: New World Graphics
# End of items scraping for *New World Graphics*
# Brand 1191: Karen Scott
# End of items scraping for *Karen Scott*
# Brand 1192: EmojiNation
# End of items scraping for *EmojiNation*
# Brand 1193: Solo
# End of items scraping for *Solo*
# Brand 1194: Pour Le Monde
# End of items scraping for *Pour Le Monde*
# Brand 1195: Art of Shaving
# End of items scraping for *Art of Shaving*
# Brand 1196: Heys
# End of items scraping for *Heys*
# Brand 1197: Taylor
# End of items scraping for *Taylor*
# Brand 1198: Graham & Brown
# End of items scraping for *Graham & Brown*
# Brand 1199: Mark Roberts
# End of items scraping for *Mark Roberts*
# Brand 1200: Pokemon
# End of items scraping for *Pokemon*
# Brand 1201: nuyu
# End of items scraping for *nuyu*
# Brand 1202: Ralph Lauren
# End of items scraping for *Ralph Lauren*
# Brand 1203: Cejon
# End of items scraping for *Cejon*
# Brand 1204: RAILS
# End of items scraping for *RAILS*
# Brand 1205: Nature's Spa by Paramount
# End of items scraping for *Nature's Spa by Paramount*
# Brand 1206: Allen Edmonds
# End of items scraping for *Allen Edmonds*
# Brand 1207: J America
# End of items scraping for *J America*
# Brand 1208: Anthony
# End of items scraping for *Anthony*
# Brand 1209: InStyler
# End of items scraping for *InStyler*
# Brand 1210: Wanted
# End of items scraping for *Wanted*
# Brand 1211: M-Clip
# End of items scraping for *M-Clip*
# Brand 1212: Couristan
# End of items scraping for *Couristan*
# Brand 1213: Pfaltzgraff
# End of items scraping for *Pfaltzgraff*
# Brand 1214: Silk'N
# End of items scraping for *Silk'N*
# Brand 1215: George Foreman
# End of items scraping for *George Foreman*
# Brand 1216: Hurley
# End of items scraping for *Hurley*
# Brand 1217: Monteau
# End of items scraping for *Monteau*
# Brand 1218: MacyBed
# End of items scraping for *MacyBed*
# Brand 1219: Ninja Turtles
# End of items scraping for *Ninja Turtles*
# Brand 1220: Gucci
# End of items scraping for *Gucci*
# Brand 1221: Paradigm
# End of items scraping for *Paradigm*
# Brand 1222: Tinsey
# End of items scraping for *Tinsey*
# Brand 1223: Riedel
# End of items scraping for *Riedel*
# Brand 1224: AQ Textiles
# End of items scraping for *AQ Textiles*
# Brand 1225: Carbon Copy
# End of items scraping for *Carbon Copy*
# Brand 1226: Extra Touch
# End of items scraping for *Extra Touch*
# Brand 1227: Westinghouse
# End of items scraping for *Westinghouse*
# Brand 1228: Charisma
# End of items scraping for *Charisma*
# Brand 1229: Household Essentials
# End of items scraping for *Household Essentials*
# Brand 1230: FENDI
# End of items scraping for *FENDI*
# Brand 1231: The Edit By Seventeen
# End of items scraping for *The Edit By Seventeen*
# Brand 1232: Pressbox
# End of items scraping for *Pressbox*
# Brand 1233: Crestview
# End of items scraping for *Crestview*
# Brand 1234: Burt's Bees
# End of items scraping for *Burt's Bees*
# Brand 1235: Couzon
# End of items scraping for *Couzon*
# Brand 1236: Teva
# End of items scraping for *Teva*
# Brand 1237: Elie Tahari
# ********************** Error *****************
# Brand 1238: Pink & Violet
# End of items scraping for *Pink & Violet*
# Brand 1239: Zuo
# End of items scraping for *Zuo*
# Brand 1240: COACH
# End of items scraping for *COACH*
# Brand 1241: JLA Home
# End of items scraping for *JLA Home*
# Brand 1242: Sharper Image
# End of items scraping for *Sharper Image*
# Brand 1243: Pathfinder
# End of items scraping for *Pathfinder*
# Brand 1244: Idealmark
# End of items scraping for *Idealmark*
# Brand 1245: Fashion Fair
# End of items scraping for *Fashion Fair*
# Brand 1246: Aminco
# End of items scraping for *Aminco*
# Brand 1247: STS Blue
# End of items scraping for *STS Blue*
# Brand 1248: Q Squared
# End of items scraping for *Q Squared*
# Brand 1249: Hooked Up by IOT
# End of items scraping for *Hooked Up by IOT*
# Brand 1250: Cuisinart
# End of items scraping for *Cuisinart*
# Brand 1251: Winning Solutions
# End of items scraping for *Winning Solutions*
# Brand 1252: Evy of California
# End of items scraping for *Evy of California*
# Brand 1253: ALDO
# End of items scraping for *ALDO*
# Brand 1254: Le Vian
# End of items scraping for *Le Vian*
# Brand 1255: DwellStudio
# End of items scraping for *DwellStudio*
# Brand 1256: Simpli Home
# End of items scraping for *Simpli Home*
# Brand 1257: Imperial Star
# End of items scraping for *Imperial Star*
# Brand 1258: Ariana Grande
# End of items scraping for *Ariana Grande*
# Brand 1259: Famous Stars and Straps
# ...
# Brand 1341: Royce Apparel Inc
# End of items scraping for *Royce Apparel Inc*
# Brand 1342: Brooks
# End of items scraping for *Brooks*
# Brand 1343: Soprano
# End of items scraping for *Soprano*
# Brand 1344: Calphalon
# End of items scraping for *Calphalon*
# Brand 1345: Freshman
# End of items scraping for *Freshman*
# Brand 1346: Rip Curl
# End of items scraping for *Rip Curl*
# Brand 1347: PGA TOUR
# End of items scraping for *PGA TOUR*
# Brand 1348: Nickelodeon
# End of items scraping for *Nickelodeon*
# Brand 1349: Armani Exchange
# End of items scraping for *Armani Exchange*
# Brand 1350: Zwilling Pour Homme
# End of items scraping for *Zwilling Pour Homme*
# Brand 1351: Cufflinks
# End of items scraping for *Cufflinks*
# Brand 1352: Swatch
# End of items scraping for *Swatch*
# Brand 1353: Unionbay
# End of items scraping for *Unionbay*
# Brand 1354: Fujifilm
# End of items scraping for *Fujifilm*
# Brand 1355: Nightway
# End of items scraping for *Nightway*
# Brand 1356: Wacoal
# End of items scraping for *Wacoal*
# Brand 1357: Naughty Monkey
# End of items scraping for *Naughty Monkey*
# Brand 1358: Dani Accessories
# End of items scraping for *Dani Accessories*
# Brand 1359: Dale Tiffany
# End of items scraping for *Dale Tiffany*
# Brand 1360: Caravelle New York
# End of items scraping for *Caravelle New York*
# Brand 1361: Epic Threads
# End of items scraping for *Epic Threads*
# Brand 1362: Bostonian
# End of items scraping for *Bostonian*
# Brand 1363: One Hart
# End of items scraping for *One Hart*
# Brand 1364: Lipault
# End of items scraping for *Lipault*
# Brand 1365: SL Fashions
# End of items scraping for *SL Fashions*
# Brand 1366: Free Heart
# End of items scraping for *Free Heart*
# Brand 1367: Tart Collections
# End of items scraping for *Tart Collections*
# Brand 1368: Ecco
# End of items scraping for *Ecco*
# Brand 1369: Jean Paul Gaultier
# End of items scraping for *Jean Paul Gaultier*
# Brand 1370: XOXO
# End of items scraping for *XOXO*
# Brand 1371: Signature Diamonds
# End of items scraping for *Signature Diamonds*
# Brand 1372: Jump
# End of items scraping for *Jump*
# Brand 1373: Sebby
# End of items scraping for *Sebby*
# Brand 1374: Lilyette
# End of items scraping for *Lilyette*
# Brand 1375: Seiko
# End of items scraping for *Seiko*
# Brand 1376: Wahl
# End of items scraping for *Wahl*
# Brand 1377: JBU
# End of items scraping for *JBU*
# Brand 1378: Dr. Scholl's
# End of items scraping for *Dr. Scholl's*
# Brand 1379: Revo
# End of items scraping for *Revo*
# Brand 1380: Frango Chocolates
# End of items scraping for *Frango Chocolates*
# Brand 1381: FISHBOWL
# End of items scraping for *FISHBOWL*
# Brand 1382: French Sole FS/NY
# End of items scraping for *French Sole FS/NY*
# Brand 1383: JBL
# End of items scraping for *JBL*
# Brand 1384: CHANEL
# ********************** Error *****************
# Brand 1385: Capel
# End of items scraping for *Capel*
# Brand 1386: Beautyrest
# End of items scraping for *Beautyrest*
# Brand 1387: Kipling
# End of items scraping for *Kipling*
# Brand 1388: MIU MIU
# End of items scraping for *MIU MIU*
# Brand 1389: Yves Saint Laurent
# End of items scraping for *Yves Saint Laurent*
# Brand 1390: Madden Girl
# End of items scraping for *Madden Girl*
# Brand 1391: Michael Kors
# End of items scraping for *Michael Kors*
# Brand 1392: Isotoner Signature
# End of items scraping for *Isotoner Signature*
# Brand 1393: Schmidt Brothers
# End of items scraping for *Schmidt Brothers*
# Brand 1394: Staub
# End of items scraping for *Staub*
# Brand 1395: Keeco
# End of items scraping for *Keeco*
# Brand 1396: Urban Playground
# End of items scraping for *Urban Playground*
# Brand 1397: Emporio Armani
# End of items scraping for *Emporio Armani*
# Brand 1398: Laura Ashley
# End of items scraping for *Laura Ashley*
# Brand 1399: Peach & Lily
# End of items scraping for *Peach & Lily*
# Brand 1400: Tempur-Pedic
# End of items scraping for *Tempur-Pedic*
# Brand 1401: Big Mouth Inc.
# ********************** Error *****************
# Brand 1402: Oggi
# End of items scraping for *Oggi*
# Brand 1403: Vera Wang
# End of items scraping for *Vera Wang*
# Brand 1404: Lee Platinum
# End of items scraping for *Lee Platinum*
# Brand 1405: Gund®
# End of items scraping for *Gund®*
# Brand 1406: Tinseltown
# End of items scraping for *Tinseltown*
# Brand 1407: Jaywalker
# End of items scraping for *Jaywalker*
# Brand 1408: Narciso Rodriguez
# End of items scraping for *Narciso Rodriguez*
# Brand 1409: Glam
# End of items scraping for *Glam*
# Brand 1410: Eastland Shoe
# End of items scraping for *Eastland Shoe*
# Brand 1411: Warner's
# End of items scraping for *Warner's*
# Brand 1412: Sleep On It
# End of items scraping for *Sleep On It*
# Brand 1413: Sweet Heart Rose
# End of items scraping for *Sweet Heart Rose*
# Brand 1414: Godiva
# End of items scraping for *Godiva*
# Brand 1415: Tommy Hilfiger
# End of items scraping for *Tommy Hilfiger*
# Brand 1416: Hamilton Beach
# End of items scraping for *Hamilton Beach*
# Brand 1417: JPR
# End of items scraping for *JPR*
# Brand 1418: PANTONE UNIVERSE (TM)
# End of items scraping for *PANTONE UNIVERSE (TM)*
# Brand 1419: Waterpik
# End of items scraping for *Waterpik*
# Brand 1420: Lauren Madison
# End of items scraping for *Lauren Madison*
# Brand 1421: Jou Jou
# End of items scraping for *Jou Jou*
# Brand 1422: Hypnotize
# End of items scraping for *Hypnotize*
# Brand 1423: Bissell
# End of items scraping for *Bissell*
# Brand 1424: jam
# End of items scraping for *jam*
# Brand 1425: St. Tropez
# End of items scraping for *St. Tropez*
# Brand 1426: Shun
# End of items scraping for *Shun*
# Brand 1427: Levi's
# End of items scraping for *Levi's*
# Brand 1428: UGG®
# End of items scraping for *UGG®*
# Brand 1429: Maison Jules
# End of items scraping for *Maison Jules*
# Brand 1430: BOSS
# End of items scraping for *BOSS*
# Brand 1431: Gorham
# End of items scraping for *Gorham*
# Brand 1432: Crocs
# End of items scraping for *Crocs*
# Brand 1433: Unity
# End of items scraping for *Unity*
# Brand 1434: Yellow Box
# End of items scraping for *Yellow Box*
# Brand 1435: Maidenform
# End of items scraping for *Maidenform*
# Brand 1436: Nordic Ware
# End of items scraping for *Nordic Ware*
# Brand 1437: Delsey
# End of items scraping for *Delsey*
# Brand 1438: It's Our Time
# End of items scraping for *It's Our Time*
# Brand 1439: Blueberi Boulevard
# End of items scraping for *Blueberi Boulevard*
# Brand 1440: Marc Fisher
# End of items scraping for *Marc Fisher*
# Brand 1441: Shiraleah
# End of items scraping for *Shiraleah*
# Brand 1442: Dermablend
# End of items scraping for *Dermablend*
# Brand 1443: Blue Ridge
# End of items scraping for *Blue Ridge*
# Brand 1444: Care Bears
# End of items scraping for *Care Bears*
# Brand 1445: Wrinkles Schminkles
# End of items scraping for *Wrinkles Schminkles*
# Brand 1446: Spider-Man
# End of items scraping for *Spider-Man*
# Brand 1447: Olivia & Grace
# End of items scraping for *Olivia & Grace*
# Brand 1448: Victoria Townsend
# End of items scraping for *Victoria Townsend*
# Brand 1449: Kids Headquarters
# End of items scraping for *Kids Headquarters*
# Brand 1450: Natori
# End of items scraping for *Natori*
# Brand 1451: Rosanna
# End of items scraping for *Rosanna*
# Brand 1452: Le Creuset
# End of items scraping for *Le Creuset*
# Brand 1453: Andre Assous
# End of items scraping for *Andre Assous*
# Brand 1454: Wrangler
# End of items scraping for *Wrangler*
# Brand 1455: Waverly
# End of items scraping for *Waverly*
# Brand 1456: Kenney
# End of items scraping for *Kenney*
# Brand 1457: Honora Style
# End of items scraping for *Honora Style*
# Brand 1458: Nao by Lladro
# End of items scraping for *Nao by Lladro*
# Brand 1459: R & M Richards
# End of items scraping for *R & M Richards*
# Brand 1460: No Comment
# End of items scraping for *No Comment*
# Brand 1461: Bow & Drape
# End of items scraping for *Bow & Drape*
# Brand 1462: Luigi Bormioli
# End of items scraping for *Luigi Bormioli*
# Brand 1463: McArthur Sports
# End of items scraping for *McArthur Sports*
# Brand 1464: Volcom
# End of items scraping for *Volcom*
# Brand 1465: OPI
# End of items scraping for *OPI*
# Brand 1466: 2-Kuhl
# End of items scraping for *2-Kuhl*
# Brand 1467: Barbie
# End of items scraping for *Barbie*
# Brand 1468: Joan Vass
# End of items scraping for *Joan Vass*
# Brand 1469: Rosenthal
# End of items scraping for *Rosenthal*
# Brand 1470: CHARLES by Charles David
# End of items scraping for *CHARLES by Charles David*
# Brand 1471: iluminage
# End of items scraping for *iluminage*
# Brand 1472: KID DANGEROUS
# End of items scraping for *KID DANGEROUS*
# Brand 1473: Maison Versailles
# End of items scraping for *Maison Versailles*
# Brand 1474: Game Time
# End of items scraping for *Game Time*
# Brand 1475: Hot Wheels
# End of items scraping for *Hot Wheels*
# Brand 1476: Graco
# End of items scraping for *Graco*
# Brand 1477: Playground Pals
# End of items scraping for *Playground Pals*
# Brand 1478: Fabrique Innovations
# End of items scraping for *Fabrique Innovations*
# Brand 1479: Dena
# End of items scraping for *Dena*
# Brand 1480: AND1
# End of items scraping for *AND1*
# Brand 1481: BLANK NYC
# End of items scraping for *BLANK NYC*
# Brand 1482: Bardwil
# End of items scraping for *Bardwil*
# Brand 1483: Self Esteem
# End of items scraping for *Self Esteem*
# Brand 1484: Quiksilver
# End of items scraping for *Quiksilver*
# Brand 1485: REWIND
# End of items scraping for *REWIND*
# Brand 1486: Paul Frank
# End of items scraping for *Paul Frank*
# Brand 1487: Chi Home
# End of items scraping for *Chi Home*
# Brand 1488: Madison Park Signature
# End of items scraping for *Madison Park Signature*
# Brand 1489: BCBGeneration
# End of items scraping for *BCBGeneration*
# Brand 1490: D Style
# End of items scraping for *D Style*
# Brand 1491: Jarden Sports
# End of items scraping for *Jarden Sports*
# Brand 1492: Fever
# End of items scraping for *Fever*
# Brand 1493: Moral Fiber
# End of items scraping for *Moral Fiber*
# Brand 1494: Culver
# End of items scraping for *Culver*
# Brand 1495: Bioworld
# End of items scraping for *Bioworld*
# Brand 1496: Mi Zone
# End of items scraping for *Mi Zone*
# Brand 1497: Scribble
# End of items scraping for *Scribble*
# Brand 1498: Dopp
# End of items scraping for *Dopp*
# Brand 1499: Baby-G
# End of items scraping for *Baby-G*
# Brand 1500: Tweezerman
# End of items scraping for *Tweezerman*
# Brand 1501: Free People
# End of items scraping for *Free People*
# Brand 1502: Raviya
# End of items scraping for *Raviya*
# Brand 1503: NYX Professional Makeup
# End of items scraping for *NYX Professional Makeup*
# Brand 1504: J Queen New York
# End of items scraping for *J Queen New York*
# Brand 1505: Polo Ralph Lauren
# End of items scraping for *Polo Ralph Lauren*
# Brand 1506: Kasper
# End of items scraping for *Kasper*
# Brand 1507: G-III Sports
# End of items scraping for *G-III Sports*
# Brand 1508: G-Shock
# End of items scraping for *G-Shock*
# Brand 1509: Chef'sChoice®
# End of items scraping for *Chef'sChoice®*
# Brand 1510: kate spade new york
# End of items scraping for *kate spade new york*
# Brand 1511: New World
# End of items scraping for *New World*
# Brand 1512: Roberto Cavalli
# End of items scraping for *Roberto Cavalli*
# Brand 1513: Peter Thomas Roth
# End of items scraping for *Peter Thomas Roth*
# Brand 1514: IZOD
# End of items scraping for *IZOD*
# Brand 1515: Portmeirion
# End of items scraping for *Portmeirion*
# Brand 1516: Reason
# End of items scraping for *Reason*
# Brand 1517: Starbucks
# End of items scraping for *Starbucks*
# Brand 1518: Oster
# End of items scraping for *Oster*
# Brand 1519: NY Collection
# End of items scraping for *NY Collection*
# Brand 1520: Patra
# ********************** Error *****************
# Brand 1521: Hotel Collection
# End of items scraping for *Hotel Collection*
# Brand 1522: Oriental Weavers
# End of items scraping for *Oriental Weavers*
# Brand 1523: Eagles Wings
# End of items scraping for *Eagles Wings*
# Brand 1524: Jody Coyote
# End of items scraping for *Jody Coyote*
# Brand 1525: Elizabeth Arden
# End of items scraping for *Elizabeth Arden*
# Brand 1526: VF Licensed Sports Group
# End of items scraping for *VF Licensed Sports Group*
# Brand 1527: Jessica Simpson
# End of items scraping for *Jessica Simpson*
# Brand 1528: TONYMOLY
# End of items scraping for *TONYMOLY*
# Brand 1529: Enesco
# End of items scraping for *Enesco*
# Brand 1530: Norelco
# End of items scraping for *Norelco*
# Brand 1531: Call It Spring
# End of items scraping for *Call It Spring*
# Brand 1532: International Silver
# End of items scraping for *International Silver*
# Brand 1533: Scala
# End of items scraping for *Scala*
# Brand 1534: SUPRA
# End of items scraping for *SUPRA*
# Brand 1535: Interdesign
# End of items scraping for *Interdesign*
# Brand 1536: Boucheron
# End of items scraping for *Boucheron*
# Brand 1537: Rwanda
# End of items scraping for *Rwanda*
# Brand 1538: Harry London Candies Inc.
# End of items scraping for *Harry London Candies Inc.*
# Brand 1539: Billabong
# End of items scraping for *Billabong*
# Brand 1540: Home Design Studio
# End of items scraping for *Home Design Studio*
# Brand 1541: Spring Air
# End of items scraping for *Spring Air*
# Brand 1542: Cartier
# End of items scraping for *Cartier*
# Brand 1543: Protect-A-Bed
# End of items scraping for *Protect-A-Bed*
# Brand 1544: DERMAFLASH
# End of items scraping for *DERMAFLASH*
# Brand 1545: Clubhouse
# End of items scraping for *Clubhouse*
# Brand 1546: LRG
# End of items scraping for *LRG*
# Brand 1547: Marc Tetro
# End of items scraping for *Marc Tetro*
# Brand 1548: Cole & Mason
# End of items scraping for *Cole & Mason*
# Brand 1549: Ashley Graham
# End of items scraping for *Ashley Graham*
# Brand 1550: Love Tribe
# End of items scraping for *Love Tribe*
# Brand 1551: American Needle
# End of items scraping for *American Needle*
# Brand 1552: Charbonnel et Walker
# End of items scraping for *Charbonnel et Walker*
# Brand 1553: Jambu
# End of items scraping for *Jambu*
# Brand 1554: Modern Littles
# End of items scraping for *Modern Littles*
# Brand 1555: Miraclesuit
# End of items scraping for *Miraclesuit*
# Brand 1556: Fairfield Square Collection
# End of items scraping for *Fairfield Square Collection*
# Brand 1557: Girly Go Garter
# End of items scraping for *Girly Go Garter*
# Brand 1558: Bali
# End of items scraping for *Bali*
# Brand 1559: Vince Camuto Home
# End of items scraping for *Vince Camuto Home*
# Brand 1560: Eileen Fisher
# End of items scraping for *Eileen Fisher*
# Brand 1561: Alex Evenings
# End of items scraping for *Alex Evenings*
# Brand 1562: Avanti
# End of items scraping for *Avanti*
# Brand 1563: Remodo
# End of items scraping for *Remodo*
# Brand 1564: Escada
# End of items scraping for *Escada*
# Brand 1565: kensie
# End of items scraping for *kensie*
# Brand 1566: FEA
# End of items scraping for *FEA*
# Brand 1567: Kangol
# End of items scraping for *Kangol*
# Brand 1568: Tommy Hilfiger Home
# End of items scraping for *Tommy Hilfiger Home*
# Brand 1569: Black Pyramid
# End of items scraping for *Black Pyramid*
# Brand 1570: Kathy Ireland
# End of items scraping for *Kathy Ireland*
# Brand 1571: Orrefors
# End of items scraping for *Orrefors*
# Brand 1572: Aerosoles
# End of items scraping for *Aerosoles*
# Brand 1573: Jenni
# End of items scraping for *Jenni*
# Brand 1574: Chronos
# End of items scraping for *Chronos*
# Brand 1575: Berkshire
# End of items scraping for *Berkshire*
# Brand 1576: Miyabi
# End of items scraping for *Miyabi*
# Brand 1577: Susan G Komen
# End of items scraping for *Susan G Komen*
# Brand 1578: T-Fal
# End of items scraping for *T-Fal*
# Brand 1579: MSK
# End of items scraping for *MSK*
# Brand 1580: Honey Can Do
# End of items scraping for *Honey Can Do*
# Brand 1581: Vans
# End of items scraping for *Vans*
# Brand 1582: Converse
# End of items scraping for *Converse*
# Brand 1583: Baby Jogger
# End of items scraping for *Baby Jogger*
# Brand 1584: Marc Joseph New York
# End of items scraping for *Marc Joseph New York*
# Brand 1585: Ella Moss
# End of items scraping for *Ella Moss*
# Brand 1586: The North Face
# End of items scraping for *The North Face*
# Brand 1587: Nourison
# End of items scraping for *Nourison*
# Brand 1588: Chelsea and Theodore
# End of items scraping for *Chelsea and Theodore*
# Brand 1589: Pyrex
# End of items scraping for *Pyrex*
# Brand 1590: The Sak
# End of items scraping for *The Sak*
# Brand 1591: Adrienne Vittadini
# End of items scraping for *Adrienne Vittadini*
# Brand 1592: Northwest Company
# End of items scraping for *Northwest Company*
# Brand 1593: Bacova
# End of items scraping for *Bacova*
# Brand 1594: Young & Reckless
# End of items scraping for *Young & Reckless*
# End of scraping all items!

# %% [markdown]
# After scraping, check errors notifications in the whole process.

# %% [markdown]
# ### 4. Import multiple csv files into pandas and concatenate into the final DataFrame:

# %%
import glob

# %%
path = '.'# use your path
allFiles = glob.glob(path + "/*.csv")
final_data = pd.DataFrame()
lst = []
for fil in allFiles:
    data_file = pd.read_csv(fil, index_col = None, header = 0)
    lst.append(data_file)
final_data = pd.concat(lst).drop('Unnamed: 0', axis = 1)

# %%
final_data.shape
# Out:
# (208898, 3)

# %% [markdown]
# Save data to the file 'macys_items.csv':

# %%
save_data(final_data, 'macys_items.csv')

# %% [markdown]
# ### 5. Some Notes:

# %% [markdown]
# **How this approach could be generalized to other merchants:**

# %% [markdown]
# Websites of online merchants like Macy's, JCPenny, Nordstrom, Kohl's, Bloomingdalaccessorye's, Saks Fifth Avenue share some common features in the structure of their pages. The main page leads to several categories(Home, Men, Women, Kids...) of items, and every category have many subcategories(Clothing, Shoes, Accessories...). The annoying thing about this structure is that websites like Macys have many items appeared in multiple categories. Categories have overlapped items on pages.

# %% [markdown]
# That's because categories are not mutually exclusive from a mathematical perspective((B ∩ C) !=  ∅ ). Some categories are classified by the function of items(clothing, shoes, bed, bath), but some other categories are classified according to other rules(sales, best offers, more...). It's extremely inefficient to spend days in exploring rules of every merchants' classification.

# %% [markdown]
# In order to scrape all items on the shopping page, the conservative way is to scrape items in every root-categories and then we apply a duplicate filter method to remove duplicated items.

# %% [markdown]
# In my solution, I applied the 'BeautifulSoup' + 'requests' to complete the web scraping. The initial thinking is to extract main categories on the home page, and then drilling down from the top to the root page to record product details of every item. However, this process became much more complex when I found subcategories on Macy's have a messy classification rule. I need to build a duplicate filter method to solve this problem. From my understanding, the framework 'scrapy' is a better choice than 'BeautifulSoup' + 'requests' for handling this scarping problem.

# %% [markdown]
# So why didn't I code in 'Scrapy' framework?

# %% [markdown]
# Honestly, although it would be more efficient for both the generalization of the scarping process and the following ETL process with MongoDB, I don't have much time to rebuild the scraping process with 'scrapy' and MongoDB now. Therefore, I continue to look for a more efficient way to complete the web scraping with 'BeautifulSoup'.

# %% [markdown]
# Fortunately, I find the classification 'Brands' is the best way to get access to all items without duplicates or missingness. This is the key choice of my web scraping.

# %% [markdown]
# 'Brand' is also appeared on 'Bestbuy.com' and some other websites as a main category or sub-categories. My approach can be easily generalized to those merchants. As for some other merchants, 'Scraping All' + 'Duplicate Filter' is a more general an scalable tool.

# %% [markdown]
# **How to assess the accuracy?**

# %% [markdown]
# During the scraping, I code to record the error information and save scraped data frequently, so it's easy for me to monitor errors which may lead to inaccurate data.

# %% [markdown]
# However, items information on Macys.com is updated all the time. Data Scraping is not a one-second action. Scraped data may become slightly different at the start and the end of data scraping process. One method is to scrape data multipe times and then we compare the results to approximately assess the accuracy of data. Another method is to scrape data on several machines(or clusters on cloud) simultaneously and then we compare results to assess the accuracy.

# %% [markdown]
# **Notes:**

# %% [markdown]
# 1. I use IP proxies and temporary time sleep to get around the anti-security system of Macys.com. Fortunately, Macys.com is friendly to scraping spiders.
# 2. IP proxies are provided here: https://hidemy.name/en/proxy-list/
# 3. Scraping code can be put on AWS or other Clouds to run, I keep it running on my local machine.
